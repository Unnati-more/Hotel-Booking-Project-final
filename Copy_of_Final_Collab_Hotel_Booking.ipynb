# %% [markdown]
# <a href="https://colab.research.google.com/github/Unnati-more/Hotel-Booking-Project-final/blob/main/Copy_of_Final_Collab_Hotel_Booking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project:-** EDA Hotel Booking
# **Project Type** - EDA project (Exploratory Data Analyses)
#
#
#
# **Contribution** - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# ![Screenshot 2024-03-05 195616.png](data:image/png;base64,...)

# %% [markdown]
# Hotel Booking sector is a customer oriented sector and highly competitive market so to be in a profitable & sustainable in market various factors help us to observe Market trend and analyse the data to discover important factors that govern the Hotel bookings.
#
# For Data preparation Steps include import & Load Dataset, check shape od dataset statical information, Data Cleaning, Check Null value, remove null value and replace null value, Figure out Duplicates Value and Remove, Outlier detected and remove.
#
# Assigned room type, Optimal Length stay, Cancellation with deposit type, Cancellation due to assigned room type, • Month wise average ADR & average hotel fees per person, lead time affect the ADR, Demand of special request and meal type preferred by customers, Required car parking spaces.
#
# Repeating Guest are less in number this due to various reason for this guest not satisfied with hospitality, room assigning were diff at the time of booking rooms were different and at the time of check in assign room different due to unavailability of rooms, Higher Waiting time This may be the reason for lesser number of repeating Guest. The demand of A room type is more may be Because of A room having low cost and because of this demand of this in guest is more. Average Lead time and waiting time more in city type hotel,So city hotel due to may be in high demand. So make it guest comfortable city hotel should pre-planned so that customer due to this no cancel the bookings. Average ADR is highest in month august and lowest in November to January and average ADR per person is highest in august month in resort hotel and in city hotel may month

# %% [markdown]
# # **Problem Statement**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!
#
#
# ###      This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data.
#
# ### **Explore and analyze the data to discover important factors that govern the bookings.**

# %% [markdown]
# ### Data Description:
# **hotel** : 1)Resort Hotel 2)City Hotel).
#
# **is_canceled** :if the booking was canceled (1) or not canceled (0)
#
# **lead_time**:Number of days that elapsed between the entering date of the booking into the PMS and the arrival date.
#
#  **arrival_date_year** : arriving Year date
#
# **arrival_date_month**: arriving Month date
#
# **arrival_date_week_number** : Week number in year for arrival date
#
# **arrival_date_day_of_month** : Day of arrival date
#
# **stays_in_weekend_nights** : Number of weekend nights (Saturday or Sunday)
#
# **stays_in_week_nights** : Number of stay in  week nights i.e Monday to Friday
#
# **adults** : Number of adults
#
# **children** : Number of children
#
# **babies**: Number of babies
#
# **meal**: Type of meal preferred.
#
#   Undefined/SC – no meal package
#
#   BB – Bed & Breakfast
#
#   HB – Half board (breakfast and one other meal)
#
#   FB – Full board (breakfast, lunch and dinner)
#
# **country** : Country of origin
#
# **market_segment** : Market segment designation.
#
# TA:- Travel Agents and TO:-Tour Operators
#
# **distribution_channel**: Booking distribution channel. The term “TA” means “Travel Agents” and “TO” means “Tour Operators”
#
# **is_repeated_guest** : The booking name was from a repeated guest (1) or not (0)
#
# **previous_cancellations** : Number of previous bookings that were cancelled by the customer compare to the current booking
#
# **previous_bookings_not_canceled** : Number of previous bookings not cancelled by the customer compare to the current booking
#
# **reserved_room_type** : Code of room type reserved.
#
# **assigned_room_type** : Code for the type of room assigned to the booking.
#
# **booking_changes** : Number of changes/amendments made to the booking from the moment the booking was entered on the PMS until the moment of check-in or cancellation
#
# **deposit_type**: customer made a deposit to guarantee the booking. This variable can assume three categories:
#
# No Deposit – no deposit was made
#
# Non Refund - a deposit was made in the value of the total stay
#
# cost Refundable – a deposit was made with a value under the total cost of stay.
#
# **agent** : ID of the travel agency that made the booking
#
# **company** : ID of the company/entity that made the booking or responsible for paying the booking. ID is presented instead of designation for anonymity reasons
#
# **days_in_waiting_list** : Number of days the booking was in the waiting list before it was confirmed to the customer
#
# **customer_type** : Type of booking, assuming one of four categories:
#
# Contract - when the booking has an allotment or other type of contract associated to it
#
# Group– when the booking is associated to a group
#
# Transient– when the booking is not part of a group or contract, and is not associated to other transient booking
#
# Transient-party – when the booking is transient, but is associated to at least other transient booking
#
# **adr**: It is measured as the total revenues generated by all the occupied rooms in a hotel or lodge divided by the total number of occupied rooms over a given time period. It is a simple average that shows the revenues generated per occupied room.
#
# The average daily rate (ADR) is a useful tool to maximize revenues in the hospitality sector. The ADR is measured as the total revenues generated by all the occupied rooms in the hotel or lodge divided by the total number of occupied rooms over a given time period. The average daily rate includes only the occupied rooms and not the total available stock. List item
#
# **required_car_parking_spaces** : Number of car parking spaces required by the customer
#
# **total_of_special_requests **: Number of special requests made by the customer
#
# **reservation_status** : Reservation last status, assuming one of three categories:
#
# Check-Out– customer has checked in but already departed
#
# No-Show – customer did not check-in and did inform the hotel of the reason
#
#
#  **reservation_status_date** : Date at which the last status was set.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# ### Businees objective is to Increse booking revenue, Enhance Customer satisfaction, Market expansion, Customer Retentation,Cost management & Sustainabilty

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Mount Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Read Dataset
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Hotel Bookings.csv')

# %%
# creating a duplicated copy of data set.
df=data.copy()

# %% [markdown]
# ### Dataset First View

# %%
# Dataset top 5 Row
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# Dataset Bottom 5 Row
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# Column which Contain numerical value.
numeric_columns=df.select_dtypes(exclude=object)
numeric_columns.columns.tolist()
# Out:
# ['is_canceled',
#  'lead_time',
#  'arrival_date_year',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'adults',
#  'children',
#  'babies',
#  'is_repeated_guest',
#  'previous_cancellations',
#  'previous_bookings_not_canceled',
#  'booking_changes',
#  'agent',
#  'company',
#  'days_in_waiting_list',
#  'adr',
#  'required_car_parking_spaces',
#  'total_of_special_requests']

# %%
# Column which Contain object data
categorical_columns=df.select_dtypes(include=object)
categorical_columns.columns.tolist()
# Out:
# ['hotel',
#  'arrival_date_month',
#  'meal',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'reserved_room_type',
#  'assigned_room_type',
#  'deposit_type',
#  'customer_type',
#  'reservation_status',
#  'reservation_status_date']

# %% [markdown]
# ### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# 31994

# %% [markdown]
# ### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
Missing_values = df.isnull().sum().sort_values(ascending=False).head().reset_index().rename(columns={'index':'Columns',0:'count'})
Missing_values
# Out:
#               Columns   count
# 0             company  112593
# 1               agent   16340
# 2             country     488
# 3            children       4
# 4  reserved_room_type       0

# %%
# Visualizing the missing values

plt.figure(figsize=(20,8))
sns.heatmap(df.isnull(),cbar=False,cmap='cool')  # Heatmap to see null values in dataset
plt.title('Missing values display',fontsize=14, fontweight='bold')
plt.xlabel("Dataset Column Name",fontsize=14)

#sky blue --> Non null values
# Magenta --> null values
# Out:
# Text(0.5, 58.5815972222222, 'Dataset Column Name')

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# 1)In this dataset 119390 Rows & 32 Columns.
#
# 2)In 20 columns contains Numerical data & 12 Columns contains Object.
#
# 3)duplicates Data present in  this dataset 31994. we will remove this Duplicates from dataset.
#
# 4)Null value present in 4 Columns i.e Company, agent, country, children.
#
#    max null value present in Company columns which we can see in Heatmap visulization

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns.tolist()
# Out:
# ['hotel',
#  'is_canceled',
#  'lead_time',
#  'arrival_date_year',
#  'arrival_date_month',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'adults',
#  'children',
#  'babies',
#  'meal',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'is_repeated_guest',
#  'previous_cancellations',
#  'previous_bookings_not_canceled',
#  'reserved_room_type',
#  'assigned_room_type',
#  'booking_changes',
#  'deposit_type',
#  'agent',
#  'company',
#  'days_in_waiting_list',
#  'customer_type',
#  'adr',
#  'required_car_parking_spaces',
#  'total_of_special_requests',
#  'reservation_status',
#  'reservation_status_date']

# %%
# Dataset Describe

# Using Transpose to make visible all column

df.describe().round(3).T
# Out:
#                                    count      mean      std      min      25%  \
# is_canceled                     119390.0     0.370    0.483     0.00     0.00
# lead_time                       119390.0   104.011  106.863     0.00    18.00
# arrival_date_year               119390.0  2016.157    0.707  2015.00  2016.00
# arrival_date_week_number        119390.0    27.165   13.605     1.00    16.00
# arrival_date_day_of_month       119390.0    15.798    8.781     1.00     8.00
# stays_in_weekend_nights         119390.0     0.928    0.999     0.00     0.00
# stays_in_week_nights            119390.0     2.500    1.908     0.00     1.00
# adults                          119390.0     1.856    0.579     0.00     2.00
# children                        119386.0     0.104    0.399     0.00     0.00
# babies                          119390.0     0.008    0.097     0.00     0.00
# is_repeated_guest               119390.0     0.032    0.176     0.00     0.00
# ...

# %%
# statistical information about Object variables in data.
df.describe(include='O').T
# Out:
#                           count unique         top    freq
# hotel                    119390      2  City Hotel   79330
# arrival_date_month       119390     12      August   13877
# meal                     119390      5          BB   92310
# country                  118902    177         PRT   48590
# market_segment           119390      8   Online TA   56477
# distribution_channel     119390      5       TA/TO   97870
# reserved_room_type       119390     10           A   85994
# assigned_room_type       119390     12           A   74053
# deposit_type             119390      3  No Deposit  104641
# customer_type            119390      4   Transient   89613
# reservation_status       119390      3   Check-Out   75166
# reservation_status_date  119390    926  2015-10-21    1461

# %% [markdown]
# City hotel data i.e 79330 is more, highest i.e 113877 guest arrival  month is august, Meal selected by Guest is BB i.e breakfast. Market segment Online TA by this mode booking was done, Highest reserved room is A.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable. So that if some wrong entries like #,@,%,?,+,& in string or in integer type coloumn that we are unable to find during null value detection.
for num,col in enumerate(df.columns,1):
    print('\n')
    print(num,')\n','{} : {}'.format(col,df[col].unique().tolist()))
# Out:
# 1 )
#  hotel : ['Resort Hotel', 'City Hotel']
#
#
# 2 )
#  is_canceled : [0, 1]
#
#
# 3 )
# ...

# %% [markdown]
# No wrong entries present like #,@,%,?,+,& in string or in integer type coloumns

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Dropping company column as it contains max. null values.
df.drop(['company'],axis=1,inplace=True)

# %%
# children ,agent columns consists of less null values hence can be replaced by 0
# unavailable country data can be replaced by 'others'

df['children'].fillna(0,inplace=True)
df['country'].fillna('others',inplace=True)
df['agent'].fillna(0,inplace=True)

# %%
# children ,agent cannot be present in float datatype hence converted to integer

df['children']=df['children'].astype(int)
df['agent']=df['agent'].astype(int)

# %%
# --------adding new columns
# since column 'babies' is added in total people & logically only babies can not visit hotel hence column is removed

df['total_people'] = df['adults']+df['babies']+df['children']
df.drop(['babies'],axis=1,inplace=True)

# %%
#---------adding new column Total stay

df['total_stay']= df['stays_in_week_nights']+df['stays_in_weekend_nights']

# %% [markdown]
# ### **New Columns**

# %%
df.columns.tolist()
# Out:
# ['hotel',
#  'is_canceled',
#  'lead_time',
#  'arrival_date_year',
#  'arrival_date_month',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'adults',
#  'children',
#  'meal',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'is_repeated_guest',
#  'previous_cancellations',
#  'previous_bookings_not_canceled',
#  'reserved_room_type',
#  'assigned_room_type',
#  'booking_changes',
#  'deposit_type',
#  'agent',
#  'days_in_waiting_list',
#  'customer_type',
#  'adr',
#  'required_car_parking_spaces',
#  'total_of_special_requests',
#  'reservation_status',
#  'reservation_status_date',
#  'total_people',
#  'total_stay']

# %%
# Updated Column shape
df.shape
# Out:
# (119390, 32)

# %%
# cross-check if all null values are removed from dataframe.
df.isnull().sum().sort_values(ascending=False).head()
# Out:
# hotel                      0
# is_canceled                0
# total_people               0
# reservation_status_date    0
# reservation_status         0
# dtype: int64

# %% [markdown]
# ### **Check Again Duplicates Value**

# %%
# Finding the duplicate values.
df.duplicated().value_counts()
# Out:
# False    87389
# True     32001
# dtype: int64

# %%
# Droping the dulpicate values
df.drop_duplicates(inplace=True)

# %%
# After droping duplicates value finding any duplicate value present
df.duplicated().value_counts()
# Out:
# False    87389
# dtype: int64

# %%
# Final Rows & Columns after Dropping Duplicates
df.shape
# Out:
# (87389, 32)

# %%
# Outlier Detection

clms = ['lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children','required_car_parking_spaces', 'adr', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes']
n = 1
plt.figure(figsize=(15,10))
for column in clms:
  plt.subplot(4,4,n)
  n = n+1
  sns.boxplot(df[column])
  plt.gca().set_title('outlier in'+' '+ column,fontsize=12, fontweight='bold')
  plt.tight_layout()

# %%
# capping outliers
df.loc[df.lead_time > 500, 'lead_time'] = 500
df.loc[df.stays_in_weekend_nights >=  5, 'stays_in_weekend_nights'] = 5
df.loc[df.adults > 4, 'adults'] = 4
df.loc[df.previous_bookings_not_canceled > 0, 'previous_bookings_not_canceled'] = 1
df.loc[df.previous_cancellations > 0, 'previous_cancellations'] = 1
df.loc[df.stays_in_week_nights > 10, 'stays_in_week_nights'] = 10
df.loc[df.booking_changes > 5, 'booking_changes'] = 5
df.loc[df.required_car_parking_spaces > 5, 'required_car_parking_spaces'] = 0
df.loc[df.children > 8, 'children'] = 0
df.loc[df.adr > 1000, 'adr'] = 1000

# %%
# After Removing Outlier

clms = ['lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children','required_car_parking_spaces', 'adr', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes']
n = 1
plt.figure(figsize=(15,10))
for column in clms:
  plt.subplot(4,4,n)
  n = n+1
  sns.boxplot(df[column])
  plt.gca().set_title('outlier in'+' '+ column,fontsize=12, fontweight='bold')
  plt.tight_layout()

# %% [markdown]
# Manupulation done above :-
#
# *   Company column contains 94% Missing values , hence column is dropped
# *   agent, children column has less then 15% missing values hence replced by 0 & replaced by 'others' for country column.
#
#
# *   after removing Duplicates data has
#
# 1.   Rows -->87389
# 2.   columns--> 32

# %% [markdown]
# ### **Co-relation Matrix**

# %%
num_df = df[['is_canceled','lead_time','previous_cancellations','previous_bookings_not_canceled','booking_changes','days_in_waiting_list','adr','is_repeated_guest','required_car_parking_spaces','total_of_special_requests','total_people']]

# %%
plt.figure(figsize=(12,6))
corr=num_df.corr(method='kendall')
matrix=np.triu(corr)
sns.heatmap(corr,annot=True,mask=matrix)
plt.title('Heatmap-Strength of Correlation',fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# 1. highest positive correlation seen in repeated guest & previous_booking_not_canceled. it indicates repeated guest are not likely to canceling bookings
#
# 2. adr & total people also has positive corrlation i.e. adr increases with increase in total people.

# %% [markdown]
# ## **UNIVARIATE ANALYSIS**

# %% [markdown]
# ####  Most preferred Hotel Type?

# %%
Preference_by_customer=df.groupby('hotel',as_index=False)['hotel'].count()
Preference_by_customer
# Out:
#    hotel
# 0  53426
# 1  33963

# %%
plt.figure.figsize=(10,5)
labels = df['hotel'].value_counts().index.tolist()
sizes = df['hotel'].value_counts().tolist()
plt.pie(sizes , labels=labels ,colors=['yellow','orange'],autopct = '%.0f%%',explode = (0, 0.1),shadow=True)
plt.title('Hotel preference distribution',fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# City Hotel is more preferred over Resort Hotel
#
# 61% Bookings for City hotel , 39% booking for Resort one

# %% [markdown]
# #### Yearly Arrivals of Customers?

# %%
yearly_arrivals_of_customers=df.groupby(['hotel','arrival_date_year'])['arrival_date_year'].count()
yearly_arrivals_of_customers
# Out:
# hotel         arrival_date_year
# City Hotel    2015                  6550
#               2016                 26758
#               2017                 20118
# Resort Hotel  2015                  6761
#               2016                 15630
#               2017                 11572
# Name: arrival_date_year, dtype: int64

# %%
# Yearly arrival rate of customer
sns.countplot(data=df,hue='hotel',x='arrival_date_year')
plt.title('Yearly Bookings',fontsize=14, fontweight='bold')
plt.xlabel('Arrival date year',fontsize=12)
plt.show()

# %% [markdown]
# #### Montly Arrivals of Customers?

# %%
monthly_arrivals_of_customers=df.groupby(['hotel','arrival_date_year','arrival_date_month'])['arrival_date_month'].count().unstack()
monthly_arrivals_of_customers
# Out:
# arrival_date_month               April  August  December  February  January  \
# hotel        arrival_date_year
# City Hotel   2015                  NaN  1107.0    1020.0       NaN      NaN
#              2016               2413.0  2816.0    1994.0    1661.0   1030.0
#              2017               2667.0  2668.0       NaN    1944.0   1700.0
# Resort Hotel 2015                  NaN  1346.0     962.0       NaN      NaN
#              2016               1357.0  1607.0    1154.0    1145.0    819.0
#              2017               1471.0  1713.0       NaN    1347.0   1144.0
#
# arrival_date_month                July    June   March     May  November  \
# hotel        arrival_date_year
# City Hotel   2015                395.0     NaN     NaN     NaN     797.0
#              2016               2487.0  2285.0  2368.0  2343.0    2145.0
#              2017               2862.0  2720.0  2488.0  3069.0       NaN
# Resort Hotel 2015               1279.0     NaN     NaN     NaN     866.0
# ...

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=df,x='arrival_date_month',hue="arrival_date_year")
plt.title('Monthly arrival ',fontsize=14, fontweight='bold')
plt.xlabel('Arrival date month',fontsize=12)

plt.show()

# %% [markdown]
# ----Observation----
#
# Peak Season of Booking is May, june, july in 2017 where maximum booking occurs.
#
# in given visulization Booking rates increses year wise

# %% [markdown]
# #### Repeating guest & not-repeated guest?

# %%
repeated_guest=df.groupby(['hotel','is_repeated_guest'])['is_repeated_guest'].count().unstack()
repeated_guest
# Out:
# is_repeated_guest      0     1
# hotel
# City Hotel         51718  1708
# Resort Hotel       32256  1707

# %%
# Pie chart of Repeating guest & not-repeated guest

plt.figure.figsize=(8,5)
labels = df['is_repeated_guest'].value_counts().index.tolist()
sizes = df['is_repeated_guest'].value_counts().tolist()
plt.pie(sizes, labels= labels, autopct = '%.0f%%',explode = (0, 0.1))

y = plt.legend()
y.get_texts()[0].set_text('Not-Repeated')
y.get_texts()[1].set_text('Repeated')

plt.title('Percentage of repeated guest & non-repeated guest',fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# ------Observation-------
#
# 4% of Repeated Guests.
#
# 96% of non repeated guest.

# %% [markdown]
# #### Which agent did highest booking ?

# %%
highest_bookings=df.groupby('agent')['agent'].count().sort_values(ascending=False).head(20)
highest_bookings
highest_bookings1=pd.DataFrame(highest_bookings).rename(columns={'index':'agent','agent':'no of booking counts'})
highest_bookings1
highest_bookings1.drop(index=[0], inplace=True)
highest_bookings1
# Out:
#        no of booking counts
# agent
# 9                     28757
# 240                   13027
# 14                     3349
# 7                      3300
# 250                    2779
# 241                    1644
# 28                     1502
# 8                      1383
# 1                      1232
# 6                      1117
# 40                      986
# 314                     844
# 242                     722
# 83                      614
# 85                      524
# 243                     477
# 171                     402
# 27                      395
# 3                       363

# %%
# Here 1,2,3,4,5,6 are token / code name given to every agent agent
highest_bookings1.plot(kind='bar',color=['#FF7800'])
plt.title("Highest booking by agent",fontsize=14, fontweight='bold')
plt.xlabel("Agent",fontsize=12)
plt.ylabel("no of booking counts",fontsize=12)
plt.show()

# %% [markdown]
# -----observation----
#
# from above we can analayse that agent whose number is 9 booked highest ticket i.e 28757 tickets

# %% [markdown]
# ####which room type is prefered by customer?

# %%
room_type=df.groupby('reserved_room_type')['reserved_room_type'].count().sort_values(ascending=False)
room_type
# Out:
# reserved_room_type
# A    56546
# D    17398
# E     6048
# F     2823
# G     2052
# B      999
# C      915
# H      596
# L        6
# P        6
# Name: reserved_room_type, dtype: int64

# %%
# Here A,B,C,D,E,F,H,L,P, are rooms type name
sns.countplot(data=df,x='reserved_room_type')
plt.title('Highest demand room',fontsize=14, fontweight='bold')
plt.xlabel("Reserved room type",fontsize=12)

plt.show()

# %% [markdown]
# ----observation----
#
# A is most preferred room type amoung all

# %% [markdown]
# #### Which Meal Prefered More?

# %%
meal_prefered=df.groupby('meal')['meal'].count()
meal_prefered
# Out:
# meal
# BB           67971
# FB             360
# HB            9085
# SC            9481
# Undefined      492
# Name: meal, dtype: int64

# %%
sns.countplot(data=df,x='meal')
plt.title('Most prefered Meal',fontsize=14, fontweight='bold')
plt.xlabel("Meal",fontsize=12)
plt.show()

# Undefined/SC – no meal package
# BB – Bed & Breakfast
# HB – Half board (breakfast and one other meal – usually dinner)
# FB – Full board

# %% [markdown]
# ---Observation---
#
# BB type meal prefered by many customers

# %% [markdown]
# ####Which type of special request done most?

# %%
most_special_request=df.groupby('total_of_special_requests')['total_of_special_requests'].count().sort_values(ascending=False)
special_req=most_special_request.copy()
special_req.drop(index=[0],inplace=True)
special_req=pd.DataFrame(special_req).rename(columns={'total_of_special_requests':'count of request'})
special_req
# Out:
#                            count of request
# total_of_special_requests
# 1                                     29016
# 2                                     11811
# 3                                      2317
# 4                                       320
# 5                                        36

# %%
special_req.plot(kind='line',color=['green'])
plt.title("Highest Special Request Type",fontsize=14.0, fontweight='bold')
plt.xlabel("special request", fontsize=12.0)
plt.ylabel(")Total count of request",fontsize=12.0)

plt.show()

# %% [markdown]
# ----Observation----
#
# special request in decreasing order from 1 to 5

# %% [markdown]
# ##**Hotel Wise Analysis**

# %% [markdown]
# ### Optimal lengh of stay in hotel?

# %%
# In total stay we have included weekendstay and weekdays and removed Cancellation booking also
plt.figure(figsize=(20,5))
not_canceled = df[df['is_canceled'] == 0]
m = not_canceled[not_canceled['total_stay'] < 15]
sns.countplot(x = m['total_stay'], hue = m['hotel'])
plt.title('Optimal length of stay',fontsize=14.0, fontweight='bold')
plt.xlabel("Total stay", fontsize=12.0)
plt.show()

# %% [markdown]
# ------Observation-------
#
# usual stay length is about 4 days.
# Mostly for couple of days (less than week) city hotel is preferred over Resort Hotel for longer stay (more than week) Resort hotel is preferred.

# %% [markdown]
# #### Which hotel has highest lead time

# %%
# The number of days duration between the Booking and actual arrival
df1=df.groupby('hotel')

high_lead_time=df1['lead_time'].median().reset_index().rename(columns = {'lead_time':'lead time by hotel'})
high_lead_time
# Out:
#           hotel  lead time by hotel
# 0    City Hotel                50.0
# 1  Resort Hotel                47.0

# %%
plt.figure(figsize = (6,3))
sns.barplot(x = high_lead_time['hotel'], y = high_lead_time['lead time by hotel'] )
plt.title("Highest Lead time in a hotel",fontsize=14.0, fontweight='bold')
plt.xlabel("Hotel", fontsize=12.0)
plt.ylabel("Lead time by hotel",fontsize=12.0)
plt.show()

# %% [markdown]
# ---observation---
#
# in city hotel lead time is 50 in resort hotel lead time is 47

# %% [markdown]
# #### Average waiting time in which type hotel is more?

# %%
#  waiting time=Number of days the booking was in the waiting list before it was confirmed to the customer
df1=df.groupby('hotel')

average_waiting_time=df1['days_in_waiting_list'].mean().reset_index().rename(columns = {'days_in_waiting_list':'avg_waitings'})
average_waiting_time
# Out:
#           hotel  avg_waitings
# 0    City Hotel      1.020271
# 1  Resort Hotel      0.323882

# %%
plt.figure(figsize = (6,3))
sns.barplot(x =average_waiting_time['hotel'], y = average_waiting_time['avg_waitings'] )
plt.title("Average waiting time ",fontsize=14.0, fontweight='bold')
plt.xlabel("Hotel", fontsize=12.0)
plt.ylabel("Average waitings",fontsize=12.0)

plt.show()

# %% [markdown]
# ----observation----
#
# by above observation we can easily find that waiting in city hotel is more as the no of customer is more in city hotel

# %% [markdown]
# ####Reserved Room Type & Assign Room type?

# %%
# reserved_room_type : here room booking done by a customer according to his choice before check in.
# assigned_room_type : Room ia alloted  by hotel executive to customer at the time of customer reached at hotel.
 # Data of Reseverd room type.
df.groupby(['hotel','reserved_room_type'])['reserved_room_type'].count().unstack()
# Out:
# reserved_room_type        A      B      C        D       E       F       G  \
# hotel
# City Hotel          37940.0  996.0   14.0  10766.0  1470.0  1757.0   479.0
# Resort Hotel        18606.0    3.0  901.0   6632.0  4578.0  1066.0  1573.0
#
# reserved_room_type      H    L    P
# hotel
# City Hotel            NaN  NaN  4.0
# Resort Hotel        596.0  6.0  2.0

# %%
# Data of assigned room type.
df.groupby(['hotel','assigned_room_type'])['assigned_room_type'].count().unstack()
# Out:
# assigned_room_type        A       B       C        D       E       F       G  \
# hotel
# City Hotel          33403.0  1661.0   161.0  13209.0  2051.0  1970.0   691.0
# Resort Hotel        12906.0   159.0  2004.0   9221.0  5144.0  1656.0  1807.0
#
# assigned_room_type      H      I      K    L    P
# hotel
# City Hotel            NaN    NaN  276.0  NaN  4.0
# Resort Hotel        706.0  357.0    NaN  1.0  2.0

# %%
# subplot of reserved room type and assigned room type.

# Reserved Room type code
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(25,5))
sns.countplot( x=df['reserved_room_type'],hue=df['hotel'],ax=ax1)
ax1.title.set_text('Reserved_room_type')

# Assigned Room type code
sns.countplot(x=df['assigned_room_type'],hue=df['hotel'] ,ax=ax2 )
ax2.title.set_text('Assigned_room_type')

# %% [markdown]
# ####Booking changes by customer in both hotels?

# %%
# Number of times booking changes done by customers.

df5=df[(df['booking_changes']!=0) & (df['booking_changes']< 10)]
df5=df5.groupby(['hotel'])['booking_changes'].value_counts()
df5
# Out:
# hotel         booking_changes
# City Hotel    1                  6023
#               2                  2068
#               3                   445
#               4                   180
#               5                   128
# Resort Hotel  1                  4879
#               2                  1440
#               3                   430
#               4                   176
#               5                   133
# Name: booking_changes, dtype: int64

# %%
plt.figure(figsize = (15,5))
df5.plot(kind='bar')
plt.title("Booking changes done by customers",fontsize=14, fontweight='bold')
plt.xlabel("Hotel Type",fontsize=12)
plt.show()

# %% [markdown]
# ---0bservation----
#
# The booking changes 1 times 2 times and so in decreasing order in both hotel done by customer

# %% [markdown]
# ###Sector from which most of the customers coming

# %%
# Transient = when the booking is not part of a group or contract, and is not associated to other transient booking
sns.countplot(data=df,x='customer_type',hue='hotel')
plt.title("Customer types hotel wise",fontsize=14, fontweight='bold')
plt.xlabel('Customer types',fontsize=12)
plt.plot()
# Out:
# []

# %% [markdown]
# ---observation---
#
# Transient booking is more done in both hotel

# %% [markdown]
# ###Reservation status btween hotels?

# %%
# Reservation last status, assuming one of three categories:
#Check-Out – customer has checked in but already departed.
# Cancellation- cancel the reserved room before Check- in.
#No-Show – customer did not check-in and did not inform the hotel of the reason.


sns.countplot(data=df,x='reservation_status',hue='hotel')
plt.title("Reservation_status",fontsize=14, fontweight='bold')
plt.xlabel(" ")
plt.plot()
# Out:
# []

# %% [markdown]
# People preference with childrens?

# %%
sns.countplot(data=df,x='children',hue='hotel')
plt.title("Preference of hotel with childrens",fontsize=14, fontweight='bold')
plt.xlabel("No of children")
plt.plot()
# Out:
# []

# %% [markdown]
# ---observation---
#
# from above analysis we can consider that most of the booking were sucessfuly checked out and hotel got revenue against it

# %% [markdown]
# # **Cancellation**

# %% [markdown]
# ### Hotel wise cancelled Booking & confirmed Booking

# %%
canclled_booking=pd.DataFrame(df.groupby(['hotel','is_canceled']).size().reset_index().rename(columns={0:'count'}))
canclled_booking

# is_canclled--> 0=Not cancled , 1=Cancled
# below Table shows sum of confirmed and Cancled booking for City & Resort Hotel
# Out:
#           hotel  is_canceled  count
# 0    City Hotel            0  37377
# 1    City Hotel            1  16049
# 2  Resort Hotel            0  25987
# 3  Resort Hotel            1   7976

# %%
#Visulization of Hotel wise Canclled Booking & Confirmed Booking
fig=plt.figure(figsize=(10,5))
ax=sns.countplot(data=df,x='hotel',hue='is_canceled')
total = float(len(df))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage, (x, y),fontsize=10)
plt.title( 'Cancelled Booking  & confirmed  Booking ',fontsize=14, fontweight='bold')
plt.xlabel(" ")
l = plt.legend()
l.get_texts()[0].set_text('confirmed')
l.get_texts()[1].set_text('Cancelled');

# %% [markdown]
# ## ----Observation----
#
# **Confirmed Booking**
#
#
#
#
# *   City Hotel Booking - *42.8%*
# *    Resort Hotel Booking - *29.7%*
#
# **Cancelled Booking**
#
# *   City Hotel- *18.4%*
# *   Resort Hotel-  *9.1%*
# .

# %% [markdown]
# ### cancellation with Deposit type

# %%
ax=sns.countplot(x='deposit_type', hue='is_canceled',data=df)
plt.title('Cancellation rate with Deposit type',fontsize=14, fontweight='bold')
plt.xlabel(" ")
total = float(len(df))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='right')

l = plt.legend()
l.get_texts()[0].set_text('Not Cancelled')
l.get_texts()[1].set_text('Cancelled');

# %% [markdown]
# ------Observation-------
#
# booking canceled -->
#
# 26% no deposit
# 1.1% non refundable
# 0% in Refundable deposit type
# No Deposit is highly preferred payment mode by customer but it comes with disadvantage for hotels as people with no deposte has highest chances of Booking cancellation

# %% [markdown]
# ### cancellation with Repeated Guest

# %%
sns.countplot(x='is_repeated_guest',hue='is_canceled',data=df)
plt.title('cancellation rate by Repeated & Non-Repeated guest',fontsize=14, fontweight='bold')
plt.xlabel(" Number of repeated guest",fontsize=12)
y = plt.legend()
y.get_texts()[0].set_text('Not Cancelled')
y.get_texts()[1].set_text('Cancelled')
plt.show()

# %% [markdown]
# ------Observation-------
#
# Repeated guests are not likely to cancel their booking.

# %% [markdown]
# ### Cancellation with  Market segment

# %%
plt.figure(figsize=(13,5))
sns.countplot(x='market_segment',hue='is_canceled',data=df)
plt.title('cancellation with Market segment ',fontsize=14, fontweight='bold')
plt.xlabel(" ")
# Out:
# Text(0.5, 0, ' ')

# %% [markdown]
# # **Time wise analysis**

# %% [markdown]
# ### Best time of Year to Book Hotel.

# %%
# ADR variation within month of continious 3 Year
# adr -> avg. daily rate

plt.figure(figsize=(20,5))
sns.lineplot(y='adr',x='arrival_date_month',hue= 'arrival_date_year',data=df)
plt.title('Adr vs Month for every year',fontsize=14, fontweight='bold')
plt.xlabel(' ')
plt.grid()
plt.show()

# %% [markdown]
# -------Observation------
#
# 1. price is Highest in August , july as we have seen these are peak months where demand of increases.(high rush --> high booking -->high adr)
#
# 2. adr is lowest in month of January , november hence this can be the best time to book hotels to get at best price.

# %% [markdown]
# ### Adr variation in a months By hotel type

# %%
# Adr variation with months
plt.figure(figsize=(20,5))
sns.lineplot(x='arrival_date_month',y='adr',hue='hotel',data=df)
plt.title('ADR Variation by Hotel-Type Monthly distribution',fontsize=14, fontweight='bold')
plt.xlabel(' ')
plt.grid()
plt.show()

# %% [markdown]
# ------Observation-------
#
# 1. it is seen that avrage daily rate for Resort hotel is fluctuating where as for city hotel it is quite stable.
#
# 2. daily rate of resort hotel is higher then city hotel in month of july,august whereas it is lower in other months
#
# 3. to book **resort in summer months**(july,aug,sept) at **best price** , booking can be done in advance where adr is less.

# %% [markdown]
# ### Repeated and Non Repeated guest pattern of arrival

# %%
# another dataframe created to know varation of repeated guest vs month
df1=df[['is_repeated_guest','arrival_date_month']].value_counts()

# df1 consist of repeated guest(=1) as well as non repeated guest(=0)
# df1[1] --> repeated guest
# df1[0] --> non-repeated guest
df1
# Out:
# is_repeated_guest  arrival_date_month
# 0                  August                11091
#                    July                   9850
#                    May                    8021
#                    April                  7636
#                    June                   7485
#                    March                  7095
#                    October                6688
#                    September              6534
#                    February               5725
#                    December               4828
#                    November               4714
#                    January                4307
# 1                  March                   418
#                    January                 386
#                    February                372
#                    May                     333
#                    December                302
#                    June                    280
#                    November                279
# ...

# %%
# lineplot for Monthly arrival of Non-Repeated guests

plt.figure(figsize=(13,5))
sns.lineplot(data=df1[0],palette='PRGn_r')
plt.title('Monthly arrival of Non-Repeated guests',fontsize=14, fontweight='bold')
plt.grid(axis='x')
plt.show()

# %% [markdown]
# ------Observation-------
#
#
# *   It is seen that crowd of Non-Repeated guests is High in August ,july
# *   Non-Repeated guests arrival drops in January ,December & November.

# %%
# lineplot for Monthly arrival of Repeated guests
plt.figure(figsize=(13,5))
sns.lineplot(data=df1[1],palette='PRGn_r')
plt.title('Monthly arrival of Repeated guests',fontsize=14, fontweight='bold')
plt.grid(axis='x')
plt.show()

# %% [markdown]
# ------Observation------
#
# *  Arrival rate of Repeated Guest is dropped in Aug month where demand is very high by Non-repeated guests (high crowd)
#
# *  Similarly when demand decreases for hotel rooms i.e. in Month of Jan Repeated guest arriaval rate increases.
#
# * Highest Repeated customers comes in month of March

# %% [markdown]
# ### Average Daily rate per person

# %%
# Average hotel fees per person
df2=df.copy()
df2['adr_per_person'] = df['adr']/(df['adults'] + df['children'])
resort_mean = df2.loc[(df2.is_canceled == 0) & (df2.hotel == 'Resort Hotel'), 'adr_per_person'].median()
city_mean = df2.loc[(df2.is_canceled == 0) & (df2.hotel == 'City Hotel'), 'adr_per_person'].median()
print("The median price of Resort hotel is{:.2f}".format(resort_mean))
print ("The median price of city hotel is {:.2f}".format(city_mean))
# Out:
# The median price of Resort hotel is41.11
# The median price of city hotel is 53.55

# %%
plt.figure(figsize=(15,5))

#total_arriving_guest['price'] = total_arriving_guest['adr'] * (total_arriving_guest['total_stay'])

sns.lineplot(x= df2['arrival_date_month'], y= df2['adr_per_person'], hue= df2['hotel'])
plt.title('Average Daily rate per person',fontsize=14, fontweight='bold')

plt.grid()
plt.show()

# %% [markdown]
# ## **Special Requests**

# %% [markdown]
# ### Special request in a month

# %%
month_special_reqs=df.groupby(['arrival_date_month'])['total_of_special_requests'].sum().reset_index()
month_special_reqs
# Out:
#    arrival_date_month  total_of_special_requests
# 0               April                       5173
# 1              August                       9409
# 2            December                       3756
# 3            February                       3894
# 4             January                       2985
# 5                July                       7720
# 6                June                       5345
# 7               March                       4312
# 8                 May                       5557
# 9            November                       3534
# 10            October                       4706
# 11          September                       4658

# %%
#plt.figure(figsize=(25,8))
month_special_reqs.plot(kind='bar',x='arrival_date_month',y='total_of_special_requests')
plt.grid(axis='y')
plt.title('Special requests according to month',fontsize=14, fontweight='bold')
plt.ylabel('Special request count')
plt.xlabel('Arrival_date_month')
plt.show()

# %% [markdown]
# 1. special request seen in peak Months that is august & july

# %% [markdown]
# ### Visiting of Adults, No of Childrens, Total Person

# %%
fig , (ax1,ax2)=plt.subplots(1,2,figsize=(25,7))
df3=df[df['adults']<6]
df4=df[df['total_people']<6]

# Number of Adults Visits.

sns.countplot(data=df3 , x='adults',hue='total_of_special_requests', ax=ax1 )
ax1.title.set_text('Number of adults')

# Number of Total Person Visits

# Total people = adults + childrens + babies.
sns.countplot(data=df4 , x='total_people',hue='total_of_special_requests' , ax=ax2 )
ax2.title.set_text('Total people')

# %% [markdown]
# ----Observations----
#
# 1. highest special requests by adults in pair.
# 2. in total people less than avg special request seen.

# %% [markdown]
# ## **Country**

# %% [markdown]
# Top 10 country visitors along with its count

# %%
plt.figure(figsize=(15,5))
df5 = df['country'].value_counts().head(10)

m = sns.barplot(x=df5.index, y=df5.values)
plt.title('Top 10 Country visitors',fontsize=14, fontweight='bold')
plt.xlabel('Country')
for p in m.patches:
    m.annotate((p.get_height()),(p.get_x(), p.get_height()+100))

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# *   Provide the specific room type to customer which was choosen by customer at the time of booking
# *   If any options for any room type like Smoking/ non smoking room, higher Floor, or a room with View give details.
#
#
# *   Provide Any membership discount to increase Repetitive customer.
#
#
# * Hotel industry should offer such schemes in their off-seasons, so that hotel industry expense recover from that scheme and so that in their peak time they generate profit.
# *   Any restriction for baby child or pets, if not then improve pet friendly aminities also
#
# *   Provide relaxation In Checkout time if possible.

# %% [markdown]
# # **Conclusion**
#
#
# 1. City hotel is highly preferred over resort hotel , booking made for
#   * city hotel--> 61% ,
#   * Resort hotel-->39%
#
# 2. Most of the customers are from Transient type ( booking is not part of a group or contract)
#
# 3. **peak season - adr relation**
#
# * adr increases when demand increases & drops as demand decreases (high rush --> high booking -->high adr)
#
# 4. **Best time to book hotel room**
# * Highly preferred arraival month is August , july but adr is high during this peak season , so one can do advance booking when prices are down
#
# * To get **resort hotels** at **least price** less than 60 adr one can book hotel in **November , january**
#
# 5. **Revenue genration**
#
# * customers preferring resort-hotel more after june and crowd increases suddenly ,but **before peak season demand is very poor** in order to manage that ,Resort Hotels can increase revenue by attracting customers before peak season (june)
#
#
# 6. **Special request**
#
# * hotels are likely to recieve high special requests in peak months like August , july
#
# 7. **Optimal length of stay**
#
# * usual stay length is about 3-4 days for which city hotel is more preferred where as resort hotel is preferred fo longer stay (week)
#
#
# 8. **Most of the visitors** from western European  countries like Portugal,United Kingdom ,france,spain. more capital can be invested in this areas.
#
# 9. **Repeated Guest**
#
# * 4% of Repeated guests , it seems like repeated guests are aware about months when adr increases , as repeated guest arriaval is high in less demand months
#
# * repeated customers are less likely to cancel their bookings hence can be considered as sign of booking confirmation by this category
